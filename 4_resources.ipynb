# %% [markdown]
# # Resources for Qiskit
#
# abraham.asfaw@ibm.com<br/>
# April 2019<br/>

# %% [markdown]
# [Qiskit tutorials on Github](https://github.com/Qiskit)
# - Tutorials
# - Community-contributed notebooks
# - See upcoming changes
#
# <img src="qiskitGit.png">

# %% [markdown]
# [Qiskit tutorials on Github](https://github.com/Qiskit)
# - Tutorials
# - Community-contributed notebooks
# - See upcoming changes
#
# [Learning paths for developers](https://learnqiskit.gitbook.io/developers/)<br/>
# [Composer guide](https://learnqiskit.gitbook.io/composerguide/)

# %% [markdown]
# Good old docstrings

# %%
from qiskit import execute
from qiskit import transpiler
help(execute)
# Out:
# Help on function execute in module qiskit.tools.compiler:
#
# execute(circuits, backend, config=None, basis_gates=None, coupling_map=None, initial_layout=None, shots=1024, max_credits=10, seed=None, qobj_id=None, skip_transpiler=False, seed_mapper=None, pass_manager=None, memory=False, **kwargs)
#     Executes a set of circuits.
#
#     Args:
#         circuits (QuantumCircuit or list[QuantumCircuit]): circuits to execute
#         backend (BaseBackend): a backend to execute the circuits on
#         config (dict): dictionary of parameters (e.g. noise) used by runner
#         basis_gates (str): comma-separated basis gate set to compile to
#         coupling_map (list): coupling map (perhaps custom) to target in mapping
#         initial_layout (list): initial layout of qubits in mapping
#         shots (int): number of repetitions of each circuit, for sampling
#         max_credits (int): maximum credits to use
#         seed (int): random seed for simulators
# ...

# %%
from qiskit import Aer, BasicAer
backend = Aer.get_backend("qasm_simulator")
help(backend)
# Out:
# Help on QasmSimulator in module qiskit.providers.aer.backends.qasm_simulator object:
#
# class QasmSimulator(qiskit.providers.aer.backends.aerbackend.AerBackend)
#  |  QasmSimulator(configuration=None, provider=None)
#  |
#  |  Aer quantum circuit simulator
#  |
#  |  Backend options:
#  |
#  |      The following backend options may be used with in the
#  |      `backend_options` kwarg diction for `QasmSimulator.run` or
#  |      `qiskit.execute`
#  |
#  |      * "method" (str): Set the simulation method. Allowed values are:
#  |          * "statevector": Uses a dense statevector simulation.
#  |          * "stabilizer": uses a Clifford stabilizer state simulator that
#  |          is only valid for Clifford circuits and noise models.
#  |          * "automatic": automatically run on stabilizer simulator if
#  |          the circuit and noise model supports it, otherwise use the
#  |          statevector method (Default: "automatic").
#  |
# ...

# %%
backend = BasicAer.get_backend("qasm_simulator")
help(backend)
# Out:
# Help on QasmSimulatorPy in module qiskit.providers.builtinsimulators.qasm_simulator object:
#
# class QasmSimulatorPy(qiskit.providers.basebackend.BaseBackend)
#  |  QasmSimulatorPy(configuration=None, provider=None)
#  |
#  |  Python implementation of a qasm simulator.
#  |
#  |  Method resolution order:
#  |      QasmSimulatorPy
#  |      qiskit.providers.basebackend.BaseBackend
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, configuration=None, provider=None)
#  |      Base class for backends.
#  |
#  |      This method should initialize the module and its configuration, and
#  |      raise an exception if a component of the module is
#  |      not available.
#  |
#  |      Args:
#  |          configuration (BackendConfiguration): backend configuration
#  |          provider (BaseProvider): provider responsible for this backend
#  |
#  |      Raises:
#  |          FileNotFoundError if backend executable is not available.
# ...
